# %% [markdown]
# # Lab-customer-analysis-round-2

# %% [markdown]
# For this lab, we will be using the `marketing_customer_analysis.csv` file that you can find in the `files_for_lab` folder. Check out the `files_for_lab/about.md` to get more information if you are using the Online Excel.
#
# **Note**: For the next labs we will be using the same data file. Please save the code, so that you can re-use it later in the labs following this lab.

# %%
import pandas as pd
import numpy as np
df1 = pd.read_excel(r'C:\Users\anton\Ironhack\Week1\Day3\lab-customer-analysis-round-2\files_for_lab\excel_files\marketing_customer_analysis.xlsx')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1. Show the dataframe shape.

# %%
#show shape of data frame
df1.shape
# Out:
# (10910, 26)

# %%
#show columns
df1.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %% [markdown]
# ## 2. Standardize header names.

# %%
df1.columns = df1.columns.str.lower()

# %%
df1.columns = df1. columns.str.replace(' ','_')
df1.head()
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  ...  \
# 0     Basic   College        2011-02-18         Employed      M  ...
# 1     Basic   College        2011-01-18       Unemployed      F  ...
# 2     Basic  Bachelor        2011-02-10         Employed      M  ...
# 3  Extended   College        2011-01-11         Employed      M  ...
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    number_of_open_complaints number_of_policies     policy_type        policy  \
# ...

# %% [markdown]
# ## 3. Which columns are numerical?

# %%
df1.dtypes
# Out:
# unnamed:_0                                int64
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                 float64
# months_since_policy_inception             int64
# number_of_open_complaints               float64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# ...

# %%
#show numerical data
df1._get_numeric_data()
# Out:
#        unnamed:_0  customer_lifetime_value  income  monthly_premium_auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# ...

# %% [markdown]
# ## 4. Which columns are categorical?

# %%
#show colmns data types
df1.dtypes
# Out:
# unnamed:_0                                int64
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                 float64
# months_since_policy_inception             int64
# number_of_open_complaints               float64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# ...

# %%
#show categorical data
df1.select_dtypes('object')
# Out:
#       customer       state response  coverage education employmentstatus  \
# 0      DK49336     Arizona       No     Basic   College         Employed
# 1      KX64629  California       No     Basic   College       Unemployed
# 2      LZ68649  Washington       No     Basic  Bachelor         Employed
# 3      XL78013      Oregon      Yes  Extended   College         Employed
# 4      QA50777      Oregon       No   Premium  Bachelor    Medical Leave
# ...        ...         ...      ...       ...       ...              ...
# 10905  FE99816      Nevada       No   Premium  Bachelor       Unemployed
# 10906  KX53892      Oregon       No     Basic   College         Employed
# 10907  TL39050     Arizona       No  Extended  Bachelor         Employed
# 10908  WA60547  California       No   Premium   College         Employed
# 10909  IV32877         NaN      NaN     Basic  Bachelor       Unemployed
#
#       gender location_code marital_status     policy_type        policy  \
# ...

# %% [markdown]
# ## 5. Check and deal with `NaN` values.

# %%
#check null values per column
df1.isna().sum()
# Out:
# unnamed:_0                          0
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# ...

# %%
# for the months_since _last claim I would replace the null values with the mean
# for number of open complaints, i would insert 0 for the null values since lot of customers have not filed complaints
# I would delete state and response
# vehicle_type, type & size represent many rows. Therefore I would not delete these rows
# state and response seem unimportant, so I would leave them in

# %% [markdown]
# # Months_Since_Last_Claim

# %%
# calculate mean in columns minths since last claim
monthly_claims_mean = df1['months_since_last_claim'].mean()
monthly_claims_mean
# Out:
# 15.149070740488469

# %%
#replace null value with mean 
df1['months_since_last_claim'] = df1['months_since_last_claim'].fillna(monthly_claims_mean)
#check
df1['months_since_last_claim'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Number_of_open_complaints

# %%
#replace nall values with 0
df1['number_of_open_complaints'] = df1['number_of_open_complaints'].fillna(0)
#check
df1['number_of_open_complaints'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## 6. Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. _Hint_: If data from March does not exist, consider only January and February.

# %%
#store months in variable
months = df1.effective_to_date.dt.strftime('%m')
months
# Out:
# 0        02
# 1        01
# 2        02
# 3        01
# 4        01
#          ..
# 10905    01
# 10906    01
# 10907    02
# 10908    02
# 10909    01
# Name: effective_to_date, Length: 10910, dtype: object

# %%
#insert column and enter month values
df1.insert(26,"Month",months)
df1
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
#checking amount per month
df1['Month'].value_counts()
# Out:
# 01    5818
# 02    5092
# Name: Month, dtype: int64

# %%
#filtering Q1
Q1 = df1[df1['Month'].isin(['01','02',])]
Q1
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %% [markdown]
# ## 7. Put all the previously mentioned data transformations into a function.

# %%
#Why a function?
# -Reducing duplication of code.
# -Decomposing complex problems into simpler pieces.
# -Improving clarity of the code.
# - Reuse of code.

def cleaning (df): # we create a function that receive a parameter, in this case it will be a dataframe
    df.columns = df.columns.str.lower() # first you convert all the columns name to lowercase
    df.columns = df. columns.str.replace(' ','_') # then you replace the spaces by _
    monthly_claims_mean = df['months_since_last_claim'].mean()
    df['months_since_last_claim'] = df['months_since_last_claim'].fillna(monthly_claims_mean)
    df['number_of_open_complaints'] = df['number_of_open_complaints'].fillna(0)
        # Finally you made some changes in the month column
        months = df.effective_to_date.dt.strftime('%m')
        df.insert(26,"Month",months)
        return df

# %% [markdown]
# ## 8. BONUS

# %% [markdown]
# ### 8.1. List Comprehensions

# %% [markdown]
# #### 8.1.1 Find the capital letters (and not white space) in the sentence 'The Quick Brown Fox Jumped Over The Lazy Dog'.

# %%
sent = 'The Quick Brown Fox Jumped Over The Lazy Dog'
capitals = [] 


#storing captial letters in list capitals 
for i in sent: 
    if i.isupper():
        capitals.append(i)
capitals

# this is no list comprehension!
# Out:
# ['T', 'Q', 'B', 'F', 'J', 'O', 'T', 'L', 'D']

# %%
#solution with list comprehension:
capital =[i for i in sent if i.isupper()]
capital
# Out:
# ['T', 'Q', 'B', 'F', 'J', 'O', 'T', 'L', 'D']

# %% [markdown]
# #### 8.1.2. Use a list comprehension to create a list with the same elements rounded to 2 decimal positions.

# %%
a = [
    0.84062117, 0.48006452, 0.7876326 , 0.77109654,
    0.44409793, 0.09014516, 0.81835917, 0.87645456,
    0.7066597 , 0.09610873, 0.41247947, 0.57433389,
    0.29960807, 0.42315023, 0.34452557, 0.4751035 ,
    0.17003563, 0.46843998, 0.92796258, 0.69814654,
    0.41290051, 0.19561071, 0.16284783, 0.97016248,
    0.71725408, 0.87702738, 0.31244595, 0.76615487,
    0.20754036, 0.57871812, 0.07214068, 0.40356048,
    0.12149553, 0.53222417, 0.9976855 , 0.12536346,
    0.80930099, 0.50962849, 0.94555126, 0.33364763
]

# %%
list_rounded= [round(item,2) for item in a] # list comprehension
list_rounded
# Out:
# [0.84,
#  0.48,
#  0.79,
#  0.77,
#  0.44,
#  0.09,
#  0.82,
#  0.88,
#  0.71,
#  0.1,
#  0.41,
#  0.57,
#  0.3,
#  0.42,
#  0.34,
#  0.48,
#  0.17,
#  0.47,
#  0.93,
#  0.7,
#  0.41,
#  0.2,
#  0.16,
#  0.97,
#  0.72,
#  0.88,
#  0.31,
#  0.77,
#  0.21,
#  0.58,
#  0.07,
#  0.4,
#  0.12,
#  0.53,
#  1.0,
#  0.13,
#  0.81,
#  0.51,
#  0.95,
#  0.33]

# %% [markdown]
# ### 8.2. Lambdas

# %% [markdown]
# #### 8.2.1. Using Lambda Expressions in List Comprehensions

# %% [markdown]
# In the following challenge, we will combine two lists using a lambda expression in a list comprehension.
#
# To do this, we will need to introduce the zip function. The zip function returns an iterator of tuples.
#
# The way zip function works with list has been shown below:

# %%
#zipping both lists
zipped_list = [list(zip(a, list_rounded))]

print(zipped_list)
# Out:
# [[(0.84062117, 0.84), (0.48006452, 0.48), (0.7876326, 0.79), (0.77109654, 0.77), (0.44409793, 0.44), (0.09014516, 0.09), (0.81835917, 0.82), (0.87645456, 0.88), (0.7066597, 0.71), (0.09610873, 0.1), (0.41247947, 0.41), (0.57433389, 0.57), (0.29960807, 0.3), (0.42315023, 0.42), (0.34452557, 0.34), (0.4751035, 0.48), (0.17003563, 0.17), (0.46843998, 0.47), (0.92796258, 0.93), (0.69814654, 0.7), (0.41290051, 0.41), (0.19561071, 0.2), (0.16284783, 0.16), (0.97016248, 0.97), (0.71725408, 0.72), (0.87702738, 0.88), (0.31244595, 0.31), (0.76615487, 0.77), (0.20754036, 0.21), (0.57871812, 0.58), (0.07214068, 0.07), (0.40356048, 0.4), (0.12149553, 0.12), (0.53222417, 0.53), (0.9976855, 1.0), (0.12536346, 0.13), (0.80930099, 0.81), (0.50962849, 0.51), (0.94555126, 0.95), (0.33364763, 0.33)]]

# %% [markdown]
# In this exercise we will try to compare the elements on the same index in the two lists. We want to zip the two lists and then use a lambda expression to compare if: list1 element > list2 element

# %%
# comparing the elemnts on the same index in two lists. Zip them and then use lamda expression to compare it
list1= [1,2,3,4]
list2= [2,3,4,5]

# create the lambda function 
compare = lambda a,b: print("True") if a>b else print("false")

#use lambda in our lists
for a,b in zip(list1,list2):
    compare(a,b) #This code gives list of booleans
# Out:
# false
# false
# false
# false
